# %%
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web

style.use('ggplot')
start=dt.datetime(2010,11,21)
end=dt.datetime(2020,11,21)

df=web.DataReader('TSLA','yahoo',start,end)
print(df.head())
# Out:
#              High    Low   Open  Close     Volume  Adj Close
# Date
# 2010-11-22  6.690  6.300  6.314  6.680  7648500.0      6.680
# 2010-11-23  7.136  6.438  6.658  6.914  7889000.0      6.914
# 2010-11-24  7.194  6.866  7.054  7.094  7125000.0      7.094
# 2010-11-26  7.200  6.950  7.120  7.064  1753000.0      7.064
# 2010-11-29  7.190  6.666  7.082  6.866  5728000.0      6.866

# %%
df['100ma']=df['Adj Close'].rolling(window=100,min_periods=0).mean()   #rolling method operated to average price column with window of 100
print(df.head())
# Out:
#              High    Low   Open  Close     Volume  Adj Close   100ma
# Date
# 2010-11-22  6.690  6.300  6.314  6.680  7648500.0      6.680  6.6800
# 2010-11-23  7.136  6.438  6.658  6.914  7889000.0      6.914  6.7970
# 2010-11-24  7.194  6.866  7.054  7.094  7125000.0      7.094  6.8960
# 2010-11-26  7.200  6.950  7.120  7.064  1753000.0      7.064  6.9380
# 2010-11-29  7.190  6.666  7.082  6.866  5728000.0      6.866  6.9236

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
plt.plot(df['Adj Close'])
plt.plot(df['100ma'])

# %% [markdown]
# # Company IPOs (2019-2021)

# %% [markdown]
# An initial public offering (IPO) refers to the process when a company first sells shares of stock to the public.  In essence, the company is going from private to public.
#
# The transition from a private to a public company can be an important time for private investors to fully realize gains from their investment as it typically includes a share premium for current private investors. Meanwhile, it also allows public investors to participate in the offering.

# %% [markdown]
# # Dataset

# %% [markdown]
# Raw data: https://www.kaggle.com/shivamb/company-ipos-2019-2021 (source is https://stockanalysis.com/)

# %% [markdown]
# # Python modules used

# %% [markdown]
# pandas - dataframe manipulation
#
# matplotlib - plotting

# %%
#import modules
import pandas as pd #data processing
import numpy as np
import matplotlib.pyplot as plt #charting
import seaborn as sns

# %% [markdown]
# # Load dataset (.csv file)

# %%
#create a new data frame
df=pd.read_csv('/Users/pgadi/Desktop/Coding/Datasets/company_ipo.csv')

# %%
#view dataframe 
df
# Out:
#         ID      IPO Date Symbol                    Company Name IPO Price  \
# 0        1  Dec 21, 2021   NVAC           NorthView Acquisition    $10.00
# 1        2  Dec 21, 2021   LSPR     Larkspur Health Acquisition    $10.00
# 2        3  Dec 21, 2021   SAGA            Sagaliam Acquisition    $10.00
# 3        4  Dec 17, 2021   RCAC  Revelstone Capital Acquisition    $10.00
# 4        5  Dec 17, 2021   APCA                  AP Acquisition    $10.00
# ...    ...           ...    ...                             ...       ...
# 1760  1761  Jan 17, 2019   RBKB               Rhinebeck Bancorp    $10.00
# 1761  1762   Jan 9, 2019   BCOW       1895 Bancorp of Wisconsin    $10.00
# 1762  1763   Jan 8, 2019   MDJH                       MDJM Ltd.     $5.00
# 1763  1764   Jan 8, 2019    MTC                           MMTec     $4.00
# 1764  1765   Jan 4, 2019   SXTC       China SXT Pharmaceuticals     $4.00
#
#      Current   Return
# 0     $10.03    0.30%
# 1      $9.98   -0.20%
# ...

# %%
#check column data types
df.dtypes
# Out:
# ID               int64
# IPO Date        object
# Symbol          object
# Company Name    object
# IPO Price       object
# Current         object
# Return          object
# dtype: object

# %%
#convert IPO Date object to a datetime format
df["IPO Date"]=pd.to_datetime(df["IPO Date"])

#pull out the year of the datetime
df["IPO Year"]=df["IPO Date"].dt.year

#view dataframe with IPO Year object added to dataframe
df
# Out:
#         ID   IPO Date Symbol                    Company Name IPO Price  \
# 0        1 2021-12-21   NVAC           NorthView Acquisition    $10.00
# 1        2 2021-12-21   LSPR     Larkspur Health Acquisition    $10.00
# 2        3 2021-12-21   SAGA            Sagaliam Acquisition    $10.00
# 3        4 2021-12-17   RCAC  Revelstone Capital Acquisition    $10.00
# 4        5 2021-12-17   APCA                  AP Acquisition    $10.00
# ...    ...        ...    ...                             ...       ...
# 1760  1761 2019-01-17   RBKB               Rhinebeck Bancorp    $10.00
# 1761  1762 2019-01-09   BCOW       1895 Bancorp of Wisconsin    $10.00
# 1762  1763 2019-01-08   MDJH                       MDJM Ltd.     $5.00
# 1763  1764 2019-01-08    MTC                           MMTec     $4.00
# 1764  1765 2019-01-04   SXTC       China SXT Pharmaceuticals     $4.00
#
#      Current   Return  IPO Year
# 0     $10.03    0.30%      2021
# 1      $9.98   -0.20%      2021
# ...

# %%
#group the data by IPO Year to compute a count of IPOs that occured in each year
df.groupby(by="IPO Year").count()
# Out:
#             ID  IPO Date  Symbol  Company Name  IPO Price  Current  Return
# IPO Year
# 2019       232       232     232           232        232      232     232
# 2020       480       480     480           480        480      480     480
# 2021      1053      1053    1053          1053       1053     1053    1053

# %% [markdown]
# 232 IPOs took place in 2019.
#
# 480 IPOs took place in 2020.
#
# 1053 IPOs took place in 2021.

# %%
df.columns
# Out:
# Index(['ID', 'IPO Date', 'Symbol', 'Company Name', 'IPO Price', 'Current',
#        'Return', 'IPO Year'],
#       dtype='object')

# %%
df.Current.value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#find the top 5 IPOs with the highest current price
df.sort_values(['Current'], ascending=False)
df.head()
# Out:
#    ID   IPO Date Symbol                    Company Name IPO Price Current  \
# 0   1 2021-12-21   NVAC           NorthView Acquisition    $10.00  $10.03
# 1   2 2021-12-21   LSPR     Larkspur Health Acquisition    $10.00   $9.98
# 2   3 2021-12-21   SAGA            Sagaliam Acquisition    $10.00   $9.97
# 3   4 2021-12-17   RCAC  Revelstone Capital Acquisition    $10.00   $9.90
# 4   5 2021-12-17   APCA                  AP Acquisition    $10.00  $10.11
#
#    Return  IPO Year
# 0   0.30%      2021
# 1  -0.20%      2021
# 2  -0.30%      2021
# 3  -1.00%      2021
# 4   1.10%      2021
